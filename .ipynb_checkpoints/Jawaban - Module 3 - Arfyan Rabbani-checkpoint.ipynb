# %% [markdown]
# ## 1. Import Libraries (pandas,numpy,matplotlib.pyplot,seaborn) and set %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2. Import Data creditcard.csv and show the top 5 data

# %%
dfcc = pd.read_csv('creditcard.csv')
dfcc.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# ## 3. Show the info of the dataframe

# %%
dfcc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %% [markdown]
# ## 4. Show the describe of the dataframe

# %%
dfcc.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %% [markdown]
# ## 5. Show info table of the DF like this

# %%
def table_data(df):
    data=[]
    for item in df.columns:
        data.append([
                    item,
                    df.dtypes.loc[item],
                    df[item].isna().sum(),
                    df[item].isna().sum()/len(df[item])*100,
                    df[item].nunique(),
                    list(df[df[item].notnull()].drop_duplicates(subset=item)[item].sample(n=2))
                    ])

    df_info = pd.DataFrame(data=data, columns=['dataFeatures', 'dataType','null','nullPct','unique','uniqueSample'])
    return df_info

# %%
dfcc_info= table_data(dfcc)
dfcc_info
# Out:
#    dataFeatures dataType  null  nullPct  unique  \
# 0          Time  float64     0      0.0  124592
# 1            V1  float64     0      0.0  275663
# 2            V2  float64     0      0.0  275663
# 3            V3  float64     0      0.0  275663
# 4            V4  float64     0      0.0  275663
# 5            V5  float64     0      0.0  275663
# 6            V6  float64     0      0.0  275663
# 7            V7  float64     0      0.0  275663
# 8            V8  float64     0      0.0  275663
# 9            V9  float64     0      0.0  275663
# 10          V10  float64     0      0.0  275663
# 11          V11  float64     0      0.0  275663
# 12          V12  float64     0      0.0  275663
# 13          V13  float64     0      0.0  275663
# 14          V14  float64     0      0.0  275663
# 15          V15  float64     0      0.0  275663
# 16          V16  float64     0      0.0  275663
# 17          V17  float64     0      0.0  275663
# ...

# %% [markdown]
# ## 6. Do Standard Scaler for all variable except the target

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(dfcc.drop('Class',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(dfcc.drop('Class',axis=1))

# %%
dfcc_scl = pd.DataFrame(scaled_data,columns=dfcc.drop('Class',axis=1).columns)
dfcc_scl.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9    ...          V20       V21       V22  \
# 0  0.193679  0.082637  0.331128    ...     0.326118 -0.024923  0.382854
# 1 -0.063700  0.071253 -0.232494    ...    -0.089611 -0.307377 -0.880077
# 2  0.639776  0.207373 -1.378675    ...     0.680975  0.337632  1.063358
# 3  0.192071  0.316018 -1.262503    ...    -0.269855 -0.147443  0.007267
# 4  0.479302 -0.226510  0.744326    ...     0.529939 -0.012839  1.100011
#
#         V23       V24       V25       V26       V27       V28    Amount
# ...

# %% [markdown]
# ## 7. Do PCA for the features to make it only 10 features remaining

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=10)

# %%
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca_data = pca.transform(scaled_data)

# %%
pca_data.shape
# Out:
# (284807, 10)

# %%
dfcc_pca = pd.DataFrame(pca_data,columns=['Feature{}'.format(item) for item in range(1,11)])

# %% [markdown]
# #### and go make the data dataframe results of the PCA like below

# %%
dfcc_pca.head()
# Out:
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  0.428961 -2.539567 -0.371003 -1.206723 -0.210670 -0.331380  0.891496
# 1 -0.396559 -2.065627 -0.635935  0.788873 -0.240158  0.381198 -0.764679
# 2  1.926400 -2.529973  0.695434 -1.243772 -1.797285 -0.249771 -0.910307
# 3  0.331305 -1.771056  0.824288 -1.376996  0.414004  0.435807 -1.468240
# 4  0.011870 -1.454624  0.529926 -0.407541  0.197120 -0.332309  0.231394
#
#    Feature8  Feature9  Feature10
# 0 -0.525554  0.155412   0.128834
# 1  0.060195  0.322135   0.301061
# 2 -2.335192 -2.424489   0.097639
# 3  0.333802 -0.694879  -0.748930
# 4  0.599223 -0.127280  -0.155860

# %% [markdown]
# ## 8. Make target series dan show it value_counts in text and seaborn countplot

# %%
dfcc['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(data=dfcc, x='Class')

# %% [markdown]
# ## 9. Use K Fold (K=5,shuffle=True,random_state=42), every loop use RandomOverSampler for the training data, and then use GradientBoostingClassifier for the model

# %% [markdown]
# ## K Fold

# %%
from sklearn.model_selection import KFold

K = 5
kf = KFold(n_splits=K,shuffle = True,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
from sklearn.metrics import classification_report,confusion_matrix,matthews_corrcoef, roc_auc_score, confusion_matrix, accuracy_score, roc_curve, auc,f1_score

# %% [markdown]
# ### Functions

# %%
data = dfcc_pca
target = dfcc['Class']

# %%
def calc_error(X, y, model):
    predictions = model.predict(X)
    predicProba = model.predict_proba(X)
    matt = matthews_corrcoef(y, predictions)
    f1 = f1_score(y, predictions, average='macro')
    report = classification_report(y, predictions)
    roc_auc = roc_auc_score(y, predicProba[:,1])
    accuracy = accuracy_score(y,predictions)
    con = pd.DataFrame(data=confusion_matrix(y,predictions),columns=['P No','P Yes'],index=['A No','A Yes'])
        
    return {
            'report':report,
            'matthew':matt,
            'f1':f1,
            'roc':roc_auc,
            'accuracy':accuracy,
            'confusion':con
            }

def calc_metrics(X_train,y_train,X_test,y_test, model):
    model.fit(X_train,y_train)
    train_error = calc_error(X_train,y_train, model)
    validation_error = calc_error(X_test,y_test, model)
    
    return train_error, validation_error

def value_in_kfold(data,scoring_type):
    a = []
    for i in range(K):
        a.append(data[i][scoring_type])
    return a

# %%
train_errors = []
validation_errors = []

for train_index, val_index in kf.split(data, target):
    
    # Split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
        
    ros = RandomOverSampler(random_state = 42)
    X_ros, y_ros = ros.fit_sample(X_train,y_train)
    

    
    # Instantite model
    gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1)
    
    # Calculate Errors
    train_error, val_error = calc_metrics(X_ros,y_ros,X_val, y_val,gbc)
    
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %%
pd.Series(y_ros).value_counts()
# Out:
# 1    227459
# 0    227459
# dtype: int64

# %%
acc = value_in_kfold(train_errors,'accuracy')
matt = value_in_kfold(train_errors,'matthew')
f1 = value_in_kfold(train_errors,'f1')
roc = value_in_kfold(train_errors,'roc')
con = value_in_kfold(train_errors,'confusion')
report = value_in_kfold(train_errors,'report')

# %%
acc_v = value_in_kfold(validation_errors,'accuracy')
matt_v = value_in_kfold(validation_errors,'matthew')
f1_v = value_in_kfold(validation_errors,'f1')
roc_v = value_in_kfold(validation_errors,'roc')
con_v = value_in_kfold(validation_errors,'confusion')
report_v = value_in_kfold(validation_errors,'report')

# %%
data_set = {'Train Acc':acc,
            'Test Acc':acc_v,
            'Train ROC AUC':roc,
            'Test ROC AUC':roc_v,
            'Train F1 Score':f1,
            'Test F1 Score':f1_v,
            'Train Matthews Corr Coef':matt,
            'Test Matthews Corr Coef':matt_v}

# %%
dfcc_result = pd.DataFrame(data_set)

# %% [markdown]
# ## 10. Print the Model Evaluation like below from the K Fold

# %%
dfcc_result.head()
# Out:
#    Train Acc  Test Acc  Train ROC AUC  Test ROC AUC  Train F1 Score  \
# 0   0.979119  0.986307       0.998181      0.950288        0.979118
# 1   0.968553  0.980671       0.996163      0.937390        0.968547
# 2   0.974953  0.988115       0.997253      0.934957        0.974949
# 3   0.968585  0.987851       0.997764      0.976896        0.968573
# 4   0.971065  0.984762       0.997771      0.957062        0.971059
#
#    Test F1 Score  Train Matthews Corr Coef  Test Matthews Corr Coef
# 0       0.583412                  0.958328                 0.282073
# 1       0.557862                  0.937436                 0.236749
# 2       0.586704                  0.950213                 0.278399
# 3       0.596477                  0.937884                 0.307258
# 4       0.582822                  0.942521                 0.286003

# %%
np.mean(data_set['Train Acc'])
# Out:
# 0.9724548582413177

# %%
for item in data_set.keys():
    print('Average ' + str(item) +': ', np.mean(data_set[item]))
# Out:
# Average Train Acc:  0.9724548582413177
# Average Test Acc:  0.9855411001282093
# Average Train ROC AUC:  0.9974264939335941
# Average Test ROC AUC:  0.9513184770344715
# Average Train F1 Score:  0.9724491508939265
# Average Test F1 Score:  0.5814553484335698
# Average Train Matthews Corr Coef:  0.9452763789057693
# Average Test Matthews Corr Coef:  0.278096189108222

# %% [markdown]
# #### Training Errors Classification Reports

# %%
for n,item in enumerate(report):
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227451
#            1       0.99      0.97      0.98    227451
#
#    micro avg       0.98      0.98      0.98    454902
#    macro avg       0.98      0.98      0.98    454902
# weighted avg       0.98      0.98      0.98    454902
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    227446
#            1       0.98      0.96      0.97    227446
#
#    micro avg       0.97      0.97      0.97    454892
#    macro avg       0.97      0.97      0.97    454892
# weighted avg       0.97      0.97      0.97    454892
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98    227449
#            1       0.99      0.96      0.97    227449
#
#    micro avg       0.97      0.97      0.97    454898
#    macro avg       0.98      0.97      0.97    454898
# ...

# %% [markdown]
# #### Validation Errors Classification Reports

# %%
for n,item in enumerate(report_v):
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.10      0.84      0.17        98
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.55      0.91      0.58     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56869
#            1       0.07      0.85      0.13        93
#
#    micro avg       0.98      0.98      0.98     56962
#    macro avg       0.53      0.92      0.56     56962
# weighted avg       1.00      0.98      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56866
#            1       0.10      0.78      0.18        95
#
#    micro avg       0.99      0.99      0.99     56961
#    macro avg       0.55      0.88      0.59     56961
# ...

# %% [markdown]
# ### Print Features Importance

# %%
coef1 = pd.Series(gbc.feature_importances_, data.columns).sort_values(ascending = False)
coef1.plot(kind='bar', title='Feature Importances')

# %% [markdown]
# ## Goodluck Guys! Salam Bertasbih!
